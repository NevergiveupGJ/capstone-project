# %% [markdown]
# # This file will be sued for capstone project

# %%
import numpy as np
import pandas as pd
df = pd.read_excel('/Users/***/Desktop/OPEN **** 2010-2016.xlsx',index_col=0)

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df.isnull().sum()
# Out:
# Gender                                                                                                            0
# Age                                                                                                               2
# Academic level                                                                                                    0
# Employmentstatus                                                                                                  1
# Registrationstatus                                                                                                0
# Experiencewithonlinelearning                                                                                      0
# Whatisyourmainreasonforchoosingtotakecoursesinanonlineformat                                                      0
# WhatisyourmainreasonforchoosingtotakecoursesinanonlineformatOtherText                                         18085
# ...

# %%
df=df.drop(['WhatisyourmainreasonforchoosingtotakecoursesinanonlineformatOtherText'], axis=1)

# %%
df.isnull().sum()
# Out:
# Gender                                                                                                          0
# Age                                                                                                             2
# Academic level                                                                                                  0
# Employmentstatus                                                                                                1
# Registrationstatus                                                                                              0
# Experiencewithonlinelearning                                                                                    0
# Whatisyourmainreasonforchoosingtotakecoursesinanonlineformat                                                    0
# BasedOnYourExperienceWouldYouConsiderTakingOtherOnlineCoursesInTheFuture                                        0
# ...

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Gender                                                                                                        0
# Age                                                                                                           0
# Academic level                                                                                                0
# Employmentstatus                                                                                              0
# Registrationstatus                                                                                            0
# Experiencewithonlinelearning                                                                                  0
# Whatisyourmainreasonforchoosingtotakecoursesinanonlineformat                                                  0
# BasedOnYourExperienceWouldYouConsiderTakingOtherOnlineCoursesInTheFuture                                      0
# ...

# %%
df.shape
# Out:
# (20958, 42)

# %%
print(df.columns.values)
# Out:
# ['Gender' 'Age' 'Academic level' 'Employmentstatus' 'Registrationstatus'
#  'Experiencewithonlinelearning'
#  'Whatisyourmainreasonforchoosingtotakecoursesinanonlineformat'
#  'BasedOnYourExperienceWouldYouConsiderTakingOtherOnlineCoursesInTheFuture'
#  'D&OFigure8Theinstructorcommunicatedcoursetopics'
#  'D&OFigure9TheInstructorCommunicatedCourseGoals'
#  'D&Ofigure10theInstructorProvidedClearInstructions'
#  'D&OFigure11TheInstructorCommunicatedDueDates'
#  'FacilitationFigure12TheInstructorHelpedStudentsLearn'
#  'FacilitationFigure13TheInstructorHelpedStudentsClarifyTheirThinking'
#  'FacilitationFigure14TheInstructorKeptStudentsEngaged&Participating'
#  'FacilitationFigure15theInstructorKeptStudentsOnTask'
#  'FacilitationFigure16TheInstructorEncouragedStudentsToExploreNewIdeas'
#  'FacilitationFigure17TheInstructorEstablishedASenseOfCourseCommunity'
#  'DirectInstructionFigure18TheInstructorHelpedFocusDiscussio0nIssuesThatAidedStudentLearning'
# ...

# %% [markdown]
# ## Introduction of the business problem

# %% [markdown]
# ### This project we will try to find a new method to predict whether a studnet will enroll next semester. This project is targarted to stakeholders who insterested in how to expland the enrollment numbers, and how to improve school online teaching qualities. The research question will be: What determins a students join the online class next semester?

# %% [markdown]
# ## Data where you describe the data that will be used to solve the problem and the source of the data.

# %% [markdown]
# ### The data is from a state univeristy, they created this questionnaire and let studnets fill it after they finishing their online coruse, the researcher used the data spanning from 2010-2016, the data consists 20958 entities and 42 columns. From it the researcher will use the data from the main aspects of: Facilitation DirectInstruction AffectiveExpression OpenCommunication GroupCohesion TriggeringEvent Exploration Integration Resolution.

# %% [markdown]
# ## Methodology section which represents the main component of the report where you discuss and describe any exploratory data analysis that you did, any inferential statistical testing that you performed, if any, and what machine learnings were used and why.

# %%
In this study, I will use SVM, knn, Logistic Regression, the depdent varaible are 
the main construct of the questionnair,

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import NullFormatter
import pandas as pd
import numpy as np
import matplotlib.ticker as ticker
from sklearn import preprocessing
# %matplotlib inline

# %%
df.groupby(['Gender'])['BasedOnYourExperienceWouldYouConsiderTakingOtherOnlineCoursesInTheFuture'].value_counts(normalize=True)
# Out:
# Gender  BasedOnYourExperienceWouldYouConsiderTakingOtherOnlineCoursesInTheFuture
# Female  Yes&comma; some additional courses.                                         0.347130
#         Yes&comma; as many as possible.                                             0.331443
#         Only if absolutely necessary.                                               0.137970
#         Not sure                                                                    0.104328
#         No                                                                          0.051030
#         I choose not to answer this question.                                       0.014364
#         Yes, some additional courses.                                               0.007434
#         Yes, as many as possible.                                                   0.006300
# Male    Yes&comma; some additional courses.                                         0.344936
# ...

# %%
df.BasedOnYourExperienceWouldYouConsiderTakingOtherOnlineCoursesInTheFuture.unique()
# Out:
# array(['Yes&comma; as many as possible.', 'No', 'Not sure',
#        'Yes&comma; some additional courses.',
#        'Only if absolutely necessary.',
#        'I choose not to answer this question.',
#        'Yes, as many as possible.', 'Yes, some additional courses.'],
#       dtype=object)

# %%
df['BasedOnYourExperienceWouldYouConsiderTakingOtherOnlineCoursesInTheFuture'] = df['BasedOnYourExperienceWouldYouConsiderTakingOtherOnlineCoursesInTheFuture'].replace(['Yes&comma; as many as possible.','Yes&comma; some additional courses.'],['Yes, as many as possible.','Yes, some additional courses.'])

# %%
df.BasedOnYourExperienceWouldYouConsiderTakingOtherOnlineCoursesInTheFuture.unique()
# Out:
# array(['Yes, as many as possible.', 'No', 'Not sure',
#        'Yes, some additional courses.', 'Only if absolutely necessary.',
#        'I choose not to answer this question.'], dtype=object)

# %%
df.Gender.unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
Feature = df[['D&OFigure8Theinstructorcommunicatedcoursetopics',
 'D&OFigure9TheInstructorCommunicatedCourseGoals',
 'D&Ofigure10theInstructorProvidedClearInstructions',
 'D&OFigure11TheInstructorCommunicatedDueDates',
 'FacilitationFigure12TheInstructorHelpedStudentsLearn',
 'FacilitationFigure13TheInstructorHelpedStudentsClarifyTheirThinking',
 'FacilitationFigure14TheInstructorKeptStudentsEngaged&Participating',
 'FacilitationFigure15theInstructorKeptStudentsOnTask',
 'FacilitationFigure16TheInstructorEncouragedStudentsToExploreNewIdeas',
 'FacilitationFigure17TheInstructorEstablishedASenseOfCourseCommunity',
 'DirectInstructionFigure18TheInstructorHelpedFocusDiscussio0nIssuesThatAidedStudentLearning',
 'DirectInstructionFigure19TheInstructorGaveFeedbackThatHelpedStudents',
 'DirectInstructionFigure20TheInstructorProvidedFeedbackInATimelyFashion',
 'AffectiveExpressionFigure21GettingToK0wOthersGaveStudentsASenseOfBelongingInTheCourse',
 'AffectiveExpressionFigure 22studentsFormedDistinctImpressionsOfCourseParticipants',
 'AffectiveExpressionFigure23studentsFoundOnlineOrWebBasedCommunicationAnExcellentMediumForSocialInteraction',
 'OpenCommunicationFigure24StudentsFeltComfortableConversingOnline',
 'OpenCommunicationFigure25StudentsFeltComfortableParticipatingInDiscussions',
 'OpenCommunicationFigure26StudentsFeltComfortableInteractingWithCourseParticipants',
 'GroupCohesionFigure27StudentsFeltComfortable4ingWithOthers',
 'GroupCohesionFigure28studentsFeltTheirPointsOfViewWereAck0wledgedByOthers',
 'GroupCohesionFigure29OnlineDiscussionsHelpedStudentsDevelopASenseOfCollaboration',
 'TriggeringEventFigure30ProblemsPosedIncreasedInterestInCourseIssues',
 'TriggeringEventFigure31CourseActivitiesPiquedCuriosity',
 'TriggeringEventFigure32StudentsFeltMotivatedToExploreContentRelatedTopics',
 'ExplorationFigure33StudentsUtilizedAVarietyOfResourcesDuringTheCourse',
 'ExplorationFigure34StudentsBrainstormed&FoundRelevantInformationToAidThemInResolvingQuestions',
 'ExplorationFigure35OnlineDiscussionsHelpedStudentsAppreciateDifferentPerspectives',
 'IntegrationFigure36CombiningNewInformationHelpedStudentsAnswerQuestions',
 'IntegrationFigure37LearningActivitiesHelpedStudentsCreateSolutions',
 'IntegrationFigure38Reflectio0nCourseContent&DiscussionsHelpedStudentsUnderstandFundamentalConcepts',
 'ResolutionFigure39StudentsCanDescribeWaysToTest&ApplyTheirNewK0wledge',
 'ResolutionFigure40StudentsDevelopedSolutionsToCourseProblemsThatCanBeAppliedInPractice',
 'ResolutionFigure41StudentsCanApplyK0wledgeCreatedInTheirCoursesToWorkOrOther0nClassRelatedActivities']]

# %%
Feature = pd.concat([Feature,pd.get_dummies(data=df, columns=['Gender','Age','Academic level','Employmentstatus','Registrationstatus',
 'Experiencewithonlinelearning',
 'Whatisyourmainreasonforchoosingtotakecoursesinanonlineformat'])], axis=1)

# %%
Feature=Feature.drop(['BasedOnYourExperienceWouldYouConsiderTakingOtherOnlineCoursesInTheFuture'], axis=1)
X = Feature
X[0:5]
# Out:
#           D&OFigure8Theinstructorcommunicatedcoursetopics  \
# Semester
# 2010Fall                                              1.0
# 2010Fall                                              1.0
# 2010Fall                                              3.0
# 2010Fall                                              2.0
# 2010Fall                                              2.0
#
#           D&OFigure9TheInstructorCommunicatedCourseGoals  \
# Semester
# 2010Fall                                             1.0
# 2010Fall                                             1.0
# 2010Fall                                             1.0
# 2010Fall                                             2.0
# 2010Fall                                             1.0
#
#           D&Ofigure10theInstructorProvidedClearInstructions  \
# Semester
# 2010Fall                                                2.0
# 2010Fall                                                2.0
# ...

# %%
y = df['BasedOnYourExperienceWouldYouConsiderTakingOtherOnlineCoursesInTheFuture'].values
y[0:5]
# Out:
# array(['Yes, as many as possible.', 'Yes, as many as possible.', 'No',
#        'Not sure', 'Yes, some additional courses.'], dtype=object)

# %%
Feature.dtypes
# Out:
# D&OFigure8Theinstructorcommunicatedcoursetopics                                                               float64
# D&OFigure9TheInstructorCommunicatedCourseGoals                                                                float64
# D&Ofigure10theInstructorProvidedClearInstructions                                                             float64
# D&OFigure11TheInstructorCommunicatedDueDates                                                                  float64
# FacilitationFigure12TheInstructorHelpedStudentsLearn                                                          float64
# FacilitationFigure13TheInstructorHelpedStudentsClarifyTheirThinking                                           float64
# FacilitationFigure14TheInstructorKeptStudentsEngaged&Participating                                            float64
# FacilitationFigure15theInstructorKeptStudentsOnTask                                                           float64
# ...

# %% [markdown]
# ## K Nearest Neighbor(KNN)

# %%
y = df['BasedOnYourExperienceWouldYouConsiderTakingOtherOnlineCoursesInTheFuture'].values
y[0:5]
X= preprocessing.StandardScaler().fit(X).transform(X)
X[0:5]
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, random_state=4)
print ('Train set:', X_train.shape,  y_train.shape)
print ('Test set:', X_test.shape,  y_test.shape)
# Out:
# Train set: (16766, 112) (16766,)
# Test set: (4192, 112) (4192,)

# %%
from sklearn.neighbors import KNeighborsClassifier
k = 4
#Train Model and Predict  
neigh = KNeighborsClassifier(n_neighbors = k).fit(X_train,y_train)
neigh
yhat = neigh.predict(X_test)
yhat[0:5]
from sklearn import metrics
print("Train set Accuracy: ", metrics.accuracy_score(y_train, neigh.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, yhat))
# Out:
# Train set Accuracy:  0.6213169509722056
# Test set Accuracy:  0.41436068702290074

# %%
Ks = 10
mean_acc = np.zeros((Ks-1))
std_acc = np.zeros((Ks-1))
ConfustionMx = [];
for n in range(1,Ks):
    
    #Train Model and Predict  
    neigh = KNeighborsClassifier(n_neighbors = n).fit(X_train,y_train)
    yhat=neigh.predict(X_test)
    mean_acc[n-1] = metrics.accuracy_score(y_test, yhat)

    
    std_acc[n-1]=np.std(yhat==y_test)/np.sqrt(yhat.shape[0])

mean_acc
plt.plot(range(1,Ks),mean_acc,'g')
plt.fill_between(range(1,Ks),mean_acc - 1 * std_acc,mean_acc + 1 * std_acc, alpha=0.10)
plt.legend(('Accuracy ', '+/- 3xstd'))
plt.ylabel('Accuracy ')
plt.xlabel('Number of Nabors (K)')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Logistic regression

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.3, random_state=4)
print ('Train set:', X_train.shape,  y_train.shape)
print ('Test set:', X_test.shape,  y_test.shape)
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
LR = LogisticRegression(C=0.01, solver='liblinear').fit(X_train,y_train)
LR
yhat = LR.predict(X_test)
yhat
yhat_prob = LR.predict_proba(X_test)
yhat_prob

# %%
print( "The best accuracy was with", mean_acc.max(), "with k=", mean_acc.argmax()+1)
# Out:
# The best accuracy was with 0.44155534351145037 with k= 8

# %%
from sklearn.metrics import jaccard_similarity_score
jaccard_similarity_score(y_test, yhat)
# Out:
# 0.47662213740458015

# %%
from sklearn.metrics import log_loss
log_loss(y_test, yhat_prob)
# Out:
# 1.2611096801598614

# %%
from sklearn.metrics import f1_score
f1_score(y_test, yhat, average='weighted')
# Out:
# 0.43822200337052386

# %% [markdown]
# ## Support Vector Machine

# %%
import scipy.optimize as opt
import pylab as pl
from sklearn.model_selection import train_test_split

y = df['BasedOnYourExperienceWouldYouConsiderTakingOtherOnlineCoursesInTheFuture'].values
y[0:5]
X= preprocessing.StandardScaler().fit(X).transform(X)
X[0:5]

X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, random_state=4)
print ('Train set:', X_train.shape,  y_train.shape)
print ('Test set:', X_test.shape,  y_test.shape)
# Out:
# Train set: (16766, 112) (16766,)
# Test set: (4192, 112) (4192,)

# %%
from sklearn import svm
clf = svm.SVC(kernel='rbf')
clf.fit(X_train, y_train) 
yhat = clf.predict(X_test)
from sklearn.metrics import classification_report, confusion_matrix
import itertools
from sklearn.metrics import jaccard_similarity_score
jaccard_similarity_score(y_test, yhat)

# %%
from sklearn.metrics import f1_score
f1_score(y_test, yhat, average='weighted')
# Out:
# 0.4602137240193298

# %% [markdown]
# ## Results section where you discuss the results.

# %%
In this study, I used KNN, Logistic regression and Support Vector Machine
The results shows that KNN, when k=8, the resutls will be the highest
(Train set Accuracy:  0.6213169509722056)

# %% [markdown]
# ## Discussion section where you discuss any observations you noted and any recommendations you can make based on the results.

# %%
Becuase the dataset is so big, so all three methods prediction accurate rate is quite low
(less than .5), a better model should be explored in terms to detect the prediction accuracy.
